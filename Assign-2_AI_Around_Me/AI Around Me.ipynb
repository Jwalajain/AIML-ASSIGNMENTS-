# %%
Assignment Name: AI Around Me
Description: List 10 real-life AI applications you use daily
and explain how ML works behind each.




    1] Google Maps - which uses machine learning to analyze traffic data and
       past travel patterns to suggest the fastest routes and predict arrival time.
    2] YouTube - ML recommends videos based on watch history, likes, searches,
       and user behavior similarity.
    3] Instagram - AI ranks posts and reels using ML models that study user interactions 
       such as likes, shares, and time spent.
    4] Gmail - Machine learning filters spam emails and suggests smart replies by 
       learning from past email patterns.
    5] Google Assistant - This uses ML and natural language processing to understand voice 
       commands and improve responses over time.
    6] Amazon - ML analyzes browsing and purchase history to
       recommend products tailored to user preferences.
    7] Netflix - AI uses ML algorithms to recommend movies and shows
       based on viewing history and ratings.
    8] Spotify - Machine learning creates personalized playlists by analyzing listening
       habits and song similarities.
    9] Google Photos - It uses ML-based image recognition to group photos by faces,
       objects, and locations automatically.
    10] Paytm - AI detects fraudulent transactions by learning normal spending patterns
        and identifying unusual behavior.
