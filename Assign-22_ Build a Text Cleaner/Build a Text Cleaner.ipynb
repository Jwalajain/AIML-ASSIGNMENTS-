# %%
import re
stopwords = ["is", "am", "are", "the", "a", "an", "and", "to", "of", "in", "on", "for", "it"]
def clean_text(text):
    text = text.lower()  # lowercase
    text = re.sub(r"[^\w\s]", "", text)
    words = text.split()
    words = [word for word in words if word not in stopwords]
    
    return " ".join(words)

# Take user input
sentence = input("Enter a sentence: ")

# Clean and display
cleaned = clean_text(sentence)

print("Cleaned Text:", cleaned)
# Out:
# Original: This is a simple example to clean the TEXT, and remove punctuation!
# Cleaned : this simple example clean text remove punctuation
