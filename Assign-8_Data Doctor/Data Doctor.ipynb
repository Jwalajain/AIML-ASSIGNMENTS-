# %%
import pandas as pd

df = pd.read_csv("data.csv")

df.columns = df.columns.str.strip().str.lower()

print("Original Dataset:")
print(df)

for col in df.select_dtypes(include='number').columns:
    df[col] = df[col].fillna(df[col].mean())

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna("Unknown")

df = df.drop_duplicates()

if "city" in df.columns:
    df["city"] = df["city"].str.strip().str.lower().str.capitalize()

print("\nCleaned Dataset:")
print(df)
# Out:
# Original Dataset:
#     name   age       city  marks
# 0  Jwala  20.0  Bangalore   85.0
# 1  Rahul  21.0     Mumbai   90.0
# 2  Anita   NaN      Delhi   78.0
# 3  Kiran  22.0    Chennai    NaN
# 4   Riya  20.0        NaN   88.0
#
# Cleaned Dataset:
#     name    age       city  marks
# 0  Jwala  20.00  Bangalore  85.00
# 1  Rahul  21.00     Mumbai  90.00
# 2  Anita  20.75      Delhi  78.00
# 3  Kiran  22.00    Chennai  85.25
# 4   Riya  20.00    Unknown  88.00
