# %%
Project Title:
Smart Student Performance Prediction System


Problem Statement:
Students often struggle to understand their academic performance and 
identify areas of improvement. This project aims to predict whether a student 
is likely to perform well based on factors like study hours, attendance, and 
previous marks.


Dataset:
The dataset will include student-related data such as:
*Study hours
*Attendance percentage
*Internal marks
*Previous semester results
The dataset can be created manually or collected from academic records.


Algorithm Used:
The project will use Linear Regression (or Decision Tree as an alternative) 
to analyze the relationship between input features and student performance.
