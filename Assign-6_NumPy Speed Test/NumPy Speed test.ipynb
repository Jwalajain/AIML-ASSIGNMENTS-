# %%
import time
import numpy as np
size = 1000000
list1 = list(range(size))
list2 = list(range(size))
array1 = np.arange(size)
array2 = np.arange(size)
start = time.time()
result_list = [list1[i] + list2[i] for i in range(size)]
end = time.time()

list_time = end - start
print("List execution time:", list_time)

start = time.time()
result_array = array1 + array2
end = time.time()

array_time = end - start
print("NumPy execution time:", array_time)
# Out:
# List execution time: 0.11600017547607422
# NumPy execution time: 0.0029993057250976562
