# %%
#Assignment Name : ML Idea Generator Description : Suggest ML problems in college, healthcare, shopping and describe input → output.


College -
1] Student Performance Prediction
Problem: Predict whether a student will pass or fail
Input: Attendance, internal marks, study hours
Output: Pass / Fail prediction

2] Placement Prediction System
Problem: Predict chances of getting placed
Input: CGPA, skills, projects, mock interview scores
Output: Placement probability (High / Medium / Low)

3] Attendance Prediction System
Problem: Predict future attendance of students
Input: Past attendance records, timetable, holidays
Output: Expected attendance percentag

Healthcare -
1] Disease Prediction
Problem: Predict possible disease based on symptoms
Input: Symptoms, age, medical history
Output: Predicted disease (e.g., Diabetes, Flu)

2] Hospital Readmission Prediction
Problem: Identify patients likely to be readmitted
Input: Patient history, treatment details, age
Output: Risk level (High / Low)

3] Health Risk Prediction
Problem: Predict risk of diseases like heart attack
Input: Age, blood pressure, cholesterol, lifestyle
Output: Risk level (High / Medium / Low)

Shopping -
1] Product Recommendation System
Problem: Recommend products to users
Input: Browsing history, past purchases, ratings
Output: Personalized product suggestions

2] Fraud Detection System
Problem: Detect fraudulent transactions
Input: Transaction amount, location, user behavior
Output: Fraud / Not Fraud

3] Customer Review Sentiment Analysis
Problem: Analyze if reviews are positive or negative
Input: Text reviews
Output: Sentiment (Positive / Negative / Neutral)
